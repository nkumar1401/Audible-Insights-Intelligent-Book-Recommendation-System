# %%
import pandas as pd

# %%
df=pd.read_csv('Audible_Catlog_Advanced_Features.csv')
df.head(5)
# Out:
#                                                                                                                                                                                                                  <<<<<<< HEAD
# ﻿Book Name                                         Author        Rating Number of Reviews Price Description                                        Listening Time                                             Ranks and Genre
# Think Like a Monk: The Secret of How to Harness... Jay Shetty    4.9    371               10080 Over the past three years, Jay Shetty has becom... 10 hours and 54 minutes  ,#1 in Audible Audiobooks & Originals (See Top...
# Ikigai: The Japanese Secret to a Long and Happy... Héctor García 4.6    3682              615   Brought to you by Penguin.                         3 hours and 23 minutes   ,#2 in Audible Audiobooks & Originals (See Top...
# ...
